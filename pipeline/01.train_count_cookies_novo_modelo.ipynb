# %% [markdown]
# OBS: No Roboflow ao misturar Retangulos e Poligonos, se exportar como Yolov8 pode apresentar erros, por isso farei manualmente a conversão de COCOMM para Yolo

# %% [markdown]
# # 1. Imports

# %%
import os
import json
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Rectangle
import sys
import torch
import torchvision
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CocoDetection
from torch.cuda.amp import autocast, GradScaler
from datetime import datetime
#import onnx
#import onnxruntime as ort
from PIL import Image
import numpy as np
from torch.optim.lr_scheduler import StepLR
import time


base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(base_dir)

sys.path.append(base_dir)

# %matplotlib inline
# Out:
# c:\ProjetosPython\PICOS

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # 2.Load

# %%
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Diretório onde estão as imagens e as anotações
images_dir = r'data/inputs/train_images/COCO_20250604/train'  
annotations_path = r'data/inputs/train_images/COCO_20250604/train/_annotations.coco.json'  

# Carregar anotações COCO
with open(os.path.join(base_dir, annotations_path)) as f:
    coco_data = json.load(f)

# Criar um dicionário para mapear IDs de imagens para anotações
annotations_dict = {}
for annotation in coco_data['annotations']:
    image_id = annotation['image_id']
    if image_id not in annotations_dict:
        annotations_dict[image_id] = []
    annotations_dict[image_id].append(annotation)
images_dict = {image['id']: image['file_name'] for image in coco_data['images']}

list(images_dict.items())[:5]  # Pega as 5 primeiras entradas
# Out:
# [(0, 'SM_14_20250603_090337_jpg.rf.dca1d69cd3489e8ad7463d8f2f8a98d5.jpg'),
#  (1, 'SM_14_20250603_090323_jpg.rf.8c8e3cf1cb878c742ac66f44c0b41e2e.jpg'),
#  (2, 'SM_14_20250603_090326_jpg.rf.7b37736d5e7ca78fb4b9dab2b23e195b.jpg'),
#  (3, 'SM_14_20250603_090319_jpg.rf.4873e7ce30326f8dbdc762879a19ce3c.jpg'),
#  (4, 'SM_14_20250603_090340_jpg.rf.e39e23af91cd0752bd50ad2b902c2f41.jpg')]

# %% [markdown]
# # 3. Test Images

# %% [markdown]
# ## 3.2 Single annotation

# %%
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Função para carregar e visualizar imagens com uma anotação COCO específica
def visualize_coco_single_annotation(image_path, annotations, image_name, annotation_index):
    # Carregar a imagem
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Converter BGR para RGB
    
    # Exibir o nome da imagem e as dimensões
    height, width, channels = image.shape
    print(f"Exibindo imagem: {image_name}")
    print(f"Dimensões da imagem: {width}x{height} (largura x altura, {channels} canais)")
    
    # Criar uma figura para a imagem
    plt.figure(figsize=(10, 10))
    plt.imshow(image)

    # Carregar apenas a anotação escolhida
    if 0 <= annotation_index < len(annotations):
        annotation = annotations[annotation_index]
        x, y, w, h = annotation['bbox']  # bbox: [x, y, width, height]
        
        # Criar um retângulo para a caixa delimitadora
        rect = Rectangle((x, y), w, h, linewidth=2, edgecolor='r', facecolor='none')
        plt.gca().add_patch(rect)
        
        # Imprimir as coordenadas da bounding box
        print(f"Coordenadas da bounding box: x={x}, y={y}, width={w}, height={h}")
    else:
        print(f"Índice de anotação {annotation_index} não é válido. Existem apenas {len(annotations)} anotações.")

    plt.axis('off')  # Remover eixos
    plt.show()  # Exibir a imagem com a marcação

# Solicitar ao usuário para escolher uma imagem e uma anotação
image_choice = 15  # Escolher a imagem (ajuste conforme necessário)
annotation_choice = 0  # Escolher a anotação (ajuste conforme necessário)

# Verificar se a escolha da imagem é válida
if 0 <= image_choice < len(coco_data['images']):
    image_info = coco_data['images'][image_choice]
    image_file = image_info['file_name']
    image_path = os.path.join(base_dir, images_dir, image_file)
    image_id = image_info['id']
    
    # Obter anotações para a imagem selecionada
    annotations = annotations_dict.get(image_id, [])
    
    # Visualizar a imagem com a anotação específica
    visualize_coco_single_annotation(image_path, annotations, image_file, annotation_choice)
else:
    print("Escolha inválida!")
# Out:
# Exibindo imagem: SM_14_20250603_090324_jpg.rf.0649db2b0597f0ac69a4d81e36d98b8b.jpg
# Dimensões da imagem: 640x640 (largura x altura, 3 canais)
# Coordenadas da bounding box: x=50, y=225, width=26, height=276

# %% [markdown]
# ## 3.2 All annotations

# %%
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Função para carregar e visualizar todas as anotações de uma imagem COCO
def visualize_coco_all_annotations(image_path, annotations, image_name):
    # Carregar a imagem
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Converter BGR para RGB
    
    # Exibir o nome da imagem e as dimensões
    height, width, channels = image.shape
    print(f"Exibindo imagem: {image_name}")
    print(f"Dimensões da imagem: {width}x{height} (largura x altura, {channels} canais)")
    
    # Criar uma figura para a imagem
    plt.figure(figsize=(10, 10))
    plt.imshow(image)

    # Iterar sobre todas as anotações e desenhar as caixas delimitadoras
    for annotation in annotations:
        x, y, w, h = annotation['bbox']  # bbox: [x, y, width, height]
        
        # Criar um retângulo para a caixa delimitadora
        rect = Rectangle((x, y), w, h, linewidth=2, edgecolor='r', facecolor='none')
        plt.gca().add_patch(rect)
        
        # Imprimir as coordenadas da bounding box
        print(f"Coordenadas da bounding box: x={x}, y={y}, width={w}, height={h}")

    plt.axis('off')  # Remover eixos
    plt.show()  # Exibir a imagem com as marcações

# Solicitar ao usuário para escolher uma imagem
image_choice = 15  # Escolher a imagem (ajuste conforme necessário)

# Verificar se a escolha da imagem é válida
if 0 <= image_choice < len(coco_data['images']):
    image_info = coco_data['images'][image_choice]
    image_file = image_info['file_name']
    image_path = os.path.join(base_dir, images_dir, image_file)
    image_id = image_info['id']
    
    # Obter anotações para a imagem selecionada
    annotations = annotations_dict.get(image_id, [])
    
    # Visualizar a imagem com todas as anotações
    visualize_coco_all_annotations(image_path, annotations, image_file)
else:
    print("Escolha inválida!")
# Out:
# Exibindo imagem: SM_14_20250603_090324_jpg.rf.0649db2b0597f0ac69a4d81e36d98b8b.jpg
# Dimensões da imagem: 640x640 (largura x altura, 3 canais)
# Coordenadas da bounding box: x=50, y=225, width=26, height=276
# Coordenadas da bounding box: x=76, y=224, width=19, height=275.5
# Coordenadas da bounding box: x=96, y=223, width=21.5, height=275.5
# Coordenadas da bounding box: x=115, y=223, width=21.5, height=273
# Coordenadas da bounding box: x=137, y=223, width=25, height=273.5
# Coordenadas da bounding box: x=154, y=224, width=29.5, height=270
# Coordenadas da bounding box: x=172, y=220, width=32, height=273.5
# Coordenadas da bounding box: x=192, y=239, width=32.5, height=258.5
# Coordenadas da bounding box: x=215, y=221, width=25.5, height=272.5
# Coordenadas da bounding box: x=233, y=218, width=27, height=271.5
# Coordenadas da bounding box: x=252, y=221, width=27, height=271
# Coordenadas da bounding box: x=271, y=221, width=25, height=269
# Coordenadas da bounding box: x=293, y=220, width=23.5, height=276
# Coordenadas da bounding box: x=312, y=223, width=24, height=267.5
# Coordenadas da bounding box: x=336, y=233, width=23.5, height=264.5
# Coordenadas da bounding box: x=352, y=217, width=23.5, height=267.5
# Coordenadas da bounding box: x=373, y=225, width=25, height=263.5
# Coordenadas da bounding box: x=392, y=220, width=24, height=266.5
# Coordenadas da bounding box: x=411, y=219, width=31.5, height=269.5
# Coordenadas da bounding box: x=431, y=219, width=29, height=271
# Coordenadas da bounding box: x=450, y=219, width=31, height=271
# Coordenadas da bounding box: x=469, y=217, width=33, height=271.5
# Coordenadas da bounding box: x=490, y=218, width=29.5, height=269.5
# Coordenadas da bounding box: x=509, y=219, width=29.5, height=274
# Coordenadas da bounding box: x=533, y=241, width=27, height=250
# Coordenadas da bounding box: x=555, y=218, width=18, height=269.5
# Coordenadas da bounding box: x=573, y=235, width=23.5, height=255

# %% [markdown]
# # 4. Train Models

# %% [markdown]
# ## 4.1 Funcoes

# %%
# Iniciar
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Definir o dispositivo (GPU ou CPU)

class CustomTransform: # Transformação das imagens
    def __call__(self, img, target):
        if isinstance(img, torch.Tensor):
            return img.to(device), target  # Verifica se a imagem é tensor, caso seja já envia para o dispositivo

        img = transforms.ToTensor()(img)  # Caso não seja Tensor, transforma em tensor
        return img.to(device), target  # Envia a imagem para o dispositivo
    
    
class CustomDataset(CocoDetection): # Configuração do dataset personalizado
    def __init__(self, root, annotation, transforms=None):
        super().__init__(root, annotation)
        self.transforms = transforms

    def __getitem__(self, idx):
        img, target = super().__getitem__(idx)

        if self.transforms:
            img, target = self.transforms(img, target)  # Aplica a transformação na imagem e no target

        return img, target
    

def create_model(weights, num_classes):
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=weights)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)

    return model


def load_pretrained_model(device, model, pretrained_model_path):
    if pretrained_model_path and os.path.exists(pretrained_model_path):
        model.load_state_dict(torch.load(pretrained_model_path, map_location=device))
        print(f"Modelo carregado de: {pretrained_model_path}")

    else:
        print("Treinando modelo do zero...")

    model.to(device)
    return model


def dataset_config(images_dir, annotations_path, data_loader_batch_size):
    dataset = CustomDataset(
        root=os.path.join(base_dir, images_dir),
        annotation=os.path.join(base_dir, annotations_path),
        transforms=CustomTransform()  # Passa a transformação customizada
    )

    # Configuração do DataLoader
    data_loader = DataLoader(dataset, batch_size=data_loader_batch_size, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

    return dataset, data_loader


def run_train(device, model, data_loader, optimizer, num_epochs, save_path):
    best_loss = float('inf')  # Inicializa como infinito
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        total_boxes = 0  # Inicializa o contador de caixas
        for images, targets in data_loader:
            # Envie imagens para o dispositivo
            images = [image.to(device) for image in images]  # As imagens já são tensores

            # Processamento dos targets
            processed_targets = []
            for t in targets:
                boxes = []
                labels = []
                for annotation in t:
                    if 'bbox' in annotation and 'category_id' in annotation:  # Verifica se os campos existem
                        bbox = annotation['bbox']  # COCO: [x_min, y_min, width, height]
                        # Converte para [x_min, y_min, x_max, y_max]
                        x_min = bbox[0]
                        y_min = bbox[1]
                        width = bbox[2]
                        height = bbox[3]
                        x_max = x_min + width
                        y_max = y_min + height

                        boxes.append([x_min, y_min, x_max, y_max])
                        labels.append(annotation['category_id'])  # Adiciona o rótulo

                if boxes:  # Se houver caixas, processa
                    boxes_tensor = torch.tensor(boxes, dtype=torch.float32, device=device)  # Converte para tensor
                    labels_tensor = torch.tensor(labels, dtype=torch.int64, device=device)  # Converte para tensor

                    processed_targets.append({'boxes': boxes_tensor, 'labels': labels_tensor})
                    total_boxes += len(boxes_tensor)  # Incrementa o contador de caixas
                else:  # Para imagens sem anotações
                    processed_targets.append({
                        'boxes': torch.empty((0, 4), device=device),
                        'labels': torch.empty((0,), dtype=torch.int64, device=device)
                    })

            # Calcule a perda somente se houver caixas em algum dos targets
            if any(len(pt['boxes']) > 0 for pt in processed_targets):
                loss_dict = model(images, processed_targets)
                losses = sum(loss for loss in loss_dict.values())
                total_loss += losses.item()

                # Backpropagation
                optimizer.zero_grad()
                losses.backward()
                optimizer.step()

        average_loss = total_loss / len(data_loader)
        print(f"Epoch {epoch + 1}, Loss: {average_loss:.4f}, Total Boxes: {total_boxes}")

        # Se o loss for menor que o melhor loss, salve o modelo
        if average_loss < best_loss:
            best_loss = average_loss
            torch.save(model.state_dict(), save_path)
            print(f"Modelo salvo em: {save_path}")


def run_train_novo(device, model, data_loader, optimizer, num_epochs, save_path):
    best_loss = float('inf')
    scheduler = StepLR(optimizer, step_size=5, gamma=0.1)
    patience = 200
    epochs_no_improve = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        total_boxes = 0
        num_batches_with_loss = 0
        start_time = time.time()

        for images, targets in data_loader:
            images = [img.to(device) for img in images]

            processed_targets = []
            for t in targets:
                boxes = []
                labels = []
                for annotation in t:
                    if 'bbox' in annotation and 'category_id' in annotation:
                        x_min, y_min, w, h = annotation['bbox']
                        x_max = x_min + w
                        y_max = y_min + h
                        boxes.append([x_min, y_min, x_max, y_max])
                        labels.append(annotation['category_id'])

                if boxes:
                    boxes_tensor = torch.tensor(boxes, dtype=torch.float32, device=device)
                    labels_tensor = torch.tensor(labels, dtype=torch.int64, device=device)
                    processed_targets.append({'boxes': boxes_tensor, 'labels': labels_tensor})
                    total_boxes += len(boxes_tensor)
                else:
                    processed_targets.append({
                        'boxes': torch.empty((0, 4), device=device),
                        'labels': torch.empty((0,), dtype=torch.int64, device=device)
                    })

            if any(len(pt['boxes']) > 0 for pt in processed_targets):
                loss_dict = model(images, processed_targets)
                losses = sum(loss for loss in loss_dict.values())
                total_loss += losses.item()
                num_batches_with_loss += 1

                optimizer.zero_grad()
                losses.backward()
                optimizer.step()

        average_loss = total_loss / max(1, num_batches_with_loss)
        scheduler.step()
        elapsed = time.time() - start_time

        print(f"Epoch {epoch + 1}, Loss média: {average_loss:.4f}, Boxes: {total_boxes}, Tempo: {elapsed:.1f}s")
        if num_batches_with_loss > 0:
            print("Última loss breakdown:", {k: round(v.item(), 4) for k, v in loss_dict.items()})

        if average_loss < best_loss:
            best_loss = average_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
            print(f"Modelo salvo em: {save_path}")
        else:
            epochs_no_improve += 1
            print(f"Sem melhora. Patience: {epochs_no_improve}/{patience}")
            if epochs_no_improve >= patience:
                print("Early stopping ativado.")
                break


def load_model_eval(device, model, pretrained_model_path):  # Colocar o modelo em modo de avaliação
    model.load_state_dict(torch.load(pretrained_model_path))
    model.to(device)
    model.eval() 

    return model


def load_image_tensor(image_path):
    image = Image.open(image_path).convert("RGB")  # Carrega a imagem e converte para RGB
    transform = transforms.ToTensor()  # Define a transformação para ToTensor
    image_tensor = transform(image).unsqueeze(0)  # Converte a imagem para tensor e adiciona uma dimensão de batch
    
    return image_tensor


def visualize_predictions_image(device, model, image_tensor, threshold=0.5):
    with torch.no_grad():  # Desativar cálculo de gradientes para economizar memória
        image_tensor = image_tensor.to(device)  # Enviar imagem para o dispositivo
        predictions = model(image_tensor)  # Fazer previsões

    prediction = predictions[0]

    image = image_tensor.squeeze(0).permute(1, 2, 0).cpu().numpy()  # Transpor a imagem para (H, W, C)

    # Criar figura com duas subplots
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))

    # Exibir imagem original (sem marcações)
    ax[0].imshow(image)
    ax[0].axis('off')
    ax[0].set_title('Imagem Original', fontsize=16)

    # Exibir imagem com marcações
    ax[1].imshow(image)
    boxes = prediction['boxes'].cpu().detach().numpy()
    scores = prediction['scores'].cpu().detach().numpy()

    # Desenhar caixas delimitadoras
    for box, score in zip(boxes, scores):
        if score > threshold:  # Filtrar por pontuação
            x_min, y_min, x_max, y_max = box
            rect = patches.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                                     linewidth=2, edgecolor='r', facecolor='none')
            ax[1].add_patch(rect)

    # Exibir o número total de detecções no topo da imagem com marcações
    detections = (scores > threshold).sum()  # Contar detecções acima do limite
    ax[1].set_title(f'Detecções Totais: {detections}', fontsize=16)
    ax[1].axis('off')

    plt.show()


def load_onnx_model(device, model_onnx_path):
    onnx_model = onnx.load(model_onnx_path)
    onnx.checker.check_model(onnx_model) # Verificar se o modelo é válido
    print("Modelo ONNX é válido!")
    
    providers = ['CUDAExecutionProvider', 'CPUExecutionProvider'] if device == "cuda" else ['CPUExecutionProvider'] # Configuração do provedor (CUDA ou CPU)
    ort_session = ort.InferenceSession(model_onnx_path, providers=providers) # Carregar o modelo ONNX com o provedor desejado
    
    return ort_session


def visualize_predictions_onnx(device, ort_session, image_tensor, threshold=0.5):
    image_tensor_device = image_tensor.to(device) # Enviar a imagem para o dispositivo (GPU ou CPU)
    
    input_name = ort_session.get_inputs()[0].name
    outputs = ort_session.run(None, {input_name: image_tensor_device.cpu().numpy()})
    
    print("Inferência ONNX concluída com sucesso!")
    
    # Carregar imagem
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Extrair as saídas do modelo ONNX
    boxes, labels, scores = outputs  # Ajuste aqui se os índices forem diferentes

    # Converter para numpy array
    boxes = np.array(boxes)
    labels = np.array(labels)
    scores = np.array(scores)

    # Filtrar as detecções pelo threshold
    for box, label, score in zip(boxes, labels, scores):
        if score >= threshold:
            x1, y1, x2, y2 = map(int, box)  # Coordenadas da caixa
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            text = f"Classe {label} ({score:.2f})"
            cv2.putText(image, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Exibir a imagem com as predições
    plt.figure(figsize=(8, 8))
    plt.imshow(image)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## 4.2 Faster RCNN

# %% [markdown]
# ### 4.2.1 FP32 (Padrão)

# %%
import torch

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
# Iniciar
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Definir o dispositivo (GPU ou CPU)

# Inputs
images_dir = r'data/inputs/train_images/COCO_20250604/train' 
annotations_path = r'data/inputs/train_images/COCO_20250604/train/_annotations.coco.json' 
save_dir = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
models_path = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
pretrained_model_path = os.path.join(models_path, 'best_faster_rcnn_model_20250520_zoom.pth')  # Altere para o caminho do modelo salvo (ex: 'caminho/para/modelo.pth') ou mantenha None para treinar do zero
#pretrained_model_path = None
weights='FasterRCNN_ResNet50_FPN_Weights.COCO_V1'
num_classes = 2  # Inclua o número de classes (background + classes)
data_loader_batch_size = 8
num_epochs = 10000

# Main
model = create_model(weights, num_classes)
model = load_pretrained_model(device, model, pretrained_model_path)
dataset, data_loader = dataset_config(images_dir, annotations_path, data_loader_batch_size)

optimizer = torch.optim.SGD(model.parameters(), lr=1e-4, momentum=0.9, weight_decay=0.0005) # Defina o otimizador

print(f"Modelo está sendo treinado no dispositivo: {next(model.parameters()).device}") # Verificar se o modelo está no dispositivo correto (GPU ou CPU)

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S') # Obter o timestamp atual para nomear o modelo
save_path = os.path.join(save_dir,  f'best_faster_rcnn_model_{timestamp}.pth')

run_train_novo(device, model, data_loader, optimizer, num_epochs, save_path)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_27936\268614425.py:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_model_path, map_location=device))
# Modelo carregado de: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250520_zoom.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Modelo está sendo treinado no dispositivo: cuda:0
# Epoch 1, Loss média: 1.0631, Boxes: 2298, Tempo: 484.2s
# Última loss breakdown: {'loss_classifier': 0.0731, 'loss_box_reg': 0.2254, 'loss_objectness': 0.0852, 'loss_rpn_box_reg': 0.1442}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 2, Loss média: 0.4775, Boxes: 2298, Tempo: 475.1s
# Última loss breakdown: {'loss_classifier': 0.0637, 'loss_box_reg': 0.2422, 'loss_objectness': 0.0467, 'loss_rpn_box_reg': 0.1032}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 3, Loss média: 0.4069, Boxes: 2298, Tempo: 474.7s
# Última loss breakdown: {'loss_classifier': 0.0579, 'loss_box_reg': 0.2213, 'loss_objectness': 0.0464, 'loss_rpn_box_reg': 0.0954}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 4, Loss média: 0.3732, Boxes: 2298, Tempo: 469.6s
# Última loss breakdown: {'loss_classifier': 0.0474, 'loss_box_reg': 0.1948, 'loss_objectness': 0.0434, 'loss_rpn_box_reg': 0.0836}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 5, Loss média: 0.3599, Boxes: 2298, Tempo: 485.8s
# Última loss breakdown: {'loss_classifier': 0.0455, 'loss_box_reg': 0.1876, 'loss_objectness': 0.049, 'loss_rpn_box_reg': 0.0676}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 6, Loss média: 0.3485, Boxes: 2298, Tempo: 473.7s
# Última loss breakdown: {'loss_classifier': 0.052, 'loss_box_reg': 0.1911, 'loss_objectness': 0.0326, 'loss_rpn_box_reg': 0.0921}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 7, Loss média: 0.3450, Boxes: 2298, Tempo: 465.5s
# Última loss breakdown: {'loss_classifier': 0.0506, 'loss_box_reg': 0.2054, 'loss_objectness': 0.0407, 'loss_rpn_box_reg': 0.0818}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 8, Loss média: 0.3466, Boxes: 2298, Tempo: 476.7s
# Última loss breakdown: {'loss_classifier': 0.057, 'loss_box_reg': 0.2125, 'loss_objectness': 0.0426, 'loss_rpn_box_reg': 0.0685}
# Sem melhora. Patience: 1/200
# Epoch 9, Loss média: 0.3439, Boxes: 2298, Tempo: 465.8s
# Última loss breakdown: {'loss_classifier': 0.0513, 'loss_box_reg': 0.1748, 'loss_objectness': 0.0414, 'loss_rpn_box_reg': 0.0689}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 10, Loss média: 0.3437, Boxes: 2298, Tempo: 481.9s
# Última loss breakdown: {'loss_classifier': 0.0409, 'loss_box_reg': 0.1781, 'loss_objectness': 0.0431, 'loss_rpn_box_reg': 0.0697}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 11, Loss média: 0.3447, Boxes: 2298, Tempo: 471.0s
# Última loss breakdown: {'loss_classifier': 0.0402, 'loss_box_reg': 0.1844, 'loss_objectness': 0.0402, 'loss_rpn_box_reg': 0.072}
# Sem melhora. Patience: 1/200
# Epoch 12, Loss média: 0.3454, Boxes: 2298, Tempo: 465.5s
# Última loss breakdown: {'loss_classifier': 0.0557, 'loss_box_reg': 0.1951, 'loss_objectness': 0.0392, 'loss_rpn_box_reg': 0.0793}
# Sem melhora. Patience: 2/200
# Epoch 13, Loss média: 0.3410, Boxes: 2298, Tempo: 475.5s
# Última loss breakdown: {'loss_classifier': 0.0479, 'loss_box_reg': 0.1805, 'loss_objectness': 0.0365, 'loss_rpn_box_reg': 0.0706}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 14, Loss média: 0.3394, Boxes: 2298, Tempo: 479.3s
# Última loss breakdown: {'loss_classifier': 0.0448, 'loss_box_reg': 0.1712, 'loss_objectness': 0.0321, 'loss_rpn_box_reg': 0.0689}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 15, Loss média: 0.3502, Boxes: 2298, Tempo: 493.8s
# Última loss breakdown: {'loss_classifier': 0.0534, 'loss_box_reg': 0.1726, 'loss_objectness': 0.0374, 'loss_rpn_box_reg': 0.0725}
# Sem melhora. Patience: 1/200
# Epoch 16, Loss média: 0.3428, Boxes: 2298, Tempo: 476.1s
# Última loss breakdown: {'loss_classifier': 0.0521, 'loss_box_reg': 0.1856, 'loss_objectness': 0.037, 'loss_rpn_box_reg': 0.0774}
# Sem melhora. Patience: 2/200
# Epoch 17, Loss média: 0.3496, Boxes: 2298, Tempo: 466.9s
# Última loss breakdown: {'loss_classifier': 0.0377, 'loss_box_reg': 0.1666, 'loss_objectness': 0.0409, 'loss_rpn_box_reg': 0.0679}
# Sem melhora. Patience: 3/200
# Epoch 18, Loss média: 0.3447, Boxes: 2298, Tempo: 470.8s
# Última loss breakdown: {'loss_classifier': 0.0584, 'loss_box_reg': 0.1804, 'loss_objectness': 0.0449, 'loss_rpn_box_reg': 0.0755}
# Sem melhora. Patience: 4/200
# Epoch 19, Loss média: 0.3432, Boxes: 2298, Tempo: 473.0s
# Última loss breakdown: {'loss_classifier': 0.0459, 'loss_box_reg': 0.1895, 'loss_objectness': 0.04, 'loss_rpn_box_reg': 0.0697}
# Sem melhora. Patience: 5/200
# Epoch 20, Loss média: 0.3432, Boxes: 2298, Tempo: 475.5s
# Última loss breakdown: {'loss_classifier': 0.0459, 'loss_box_reg': 0.1807, 'loss_objectness': 0.0399, 'loss_rpn_box_reg': 0.0722}
# Sem melhora. Patience: 6/200
# Epoch 21, Loss média: 0.3422, Boxes: 2298, Tempo: 478.8s
# Última loss breakdown: {'loss_classifier': 0.0523, 'loss_box_reg': 0.1766, 'loss_objectness': 0.0337, 'loss_rpn_box_reg': 0.073}
# Sem melhora. Patience: 7/200
# Epoch 22, Loss média: 0.3419, Boxes: 2298, Tempo: 474.1s
# Última loss breakdown: {'loss_classifier': 0.0453, 'loss_box_reg': 0.1637, 'loss_objectness': 0.039, 'loss_rpn_box_reg': 0.0682}
# Sem melhora. Patience: 8/200
# Epoch 23, Loss média: 0.3427, Boxes: 2298, Tempo: 465.9s
# Última loss breakdown: {'loss_classifier': 0.0494, 'loss_box_reg': 0.1865, 'loss_objectness': 0.033, 'loss_rpn_box_reg': 0.0741}
# Sem melhora. Patience: 9/200
# Epoch 24, Loss média: 0.3450, Boxes: 2298, Tempo: 478.4s
# Última loss breakdown: {'loss_classifier': 0.0441, 'loss_box_reg': 0.1744, 'loss_objectness': 0.0386, 'loss_rpn_box_reg': 0.0683}
# Sem melhora. Patience: 10/200
# Epoch 25, Loss média: 0.3381, Boxes: 2298, Tempo: 501.2s
# Última loss breakdown: {'loss_classifier': 0.0611, 'loss_box_reg': 0.1952, 'loss_objectness': 0.0412, 'loss_rpn_box_reg': 0.0758}
# Modelo salvo em: c:\ProjetosPython\PICOS\data\inputs\ia_models\FRCNN Resnet50\best_faster_rcnn_model_20250604_111351.pth
# Epoch 26, Loss média: 0.3452, Boxes: 2298, Tempo: 498.2s
# Última loss breakdown: {'loss_classifier': 0.0461, 'loss_box_reg': 0.1882, 'loss_objectness': 0.0481, 'loss_rpn_box_reg': 0.0706}
# Sem melhora. Patience: 1/200
# Epoch 27, Loss média: 0.3428, Boxes: 2298, Tempo: 509.7s
# Última loss breakdown: {'loss_classifier': 0.0385, 'loss_box_reg': 0.1571, 'loss_objectness': 0.0299, 'loss_rpn_box_reg': 0.071}
# Sem melhora. Patience: 2/200
# Epoch 28, Loss média: 0.3444, Boxes: 2298, Tempo: 527.6s
# Última loss breakdown: {'loss_classifier': 0.0498, 'loss_box_reg': 0.1862, 'loss_objectness': 0.0365, 'loss_rpn_box_reg': 0.0677}
# Sem melhora. Patience: 3/200
# Epoch 29, Loss média: 0.3430, Boxes: 2298, Tempo: 521.3s
# Última loss breakdown: {'loss_classifier': 0.0493, 'loss_box_reg': 0.1868, 'loss_objectness': 0.0459, 'loss_rpn_box_reg': 0.0795}
# Sem melhora. Patience: 4/200
# Epoch 30, Loss média: 0.3422, Boxes: 2298, Tempo: 499.6s
# Última loss breakdown: {'loss_classifier': 0.0509, 'loss_box_reg': 0.1863, 'loss_objectness': 0.0299, 'loss_rpn_box_reg': 0.0695}
# Sem melhora. Patience: 5/200
# Epoch 31, Loss média: 0.3430, Boxes: 2298, Tempo: 508.9s
# Última loss breakdown: {'loss_classifier': 0.05, 'loss_box_reg': 0.1797, 'loss_objectness': 0.0198, 'loss_rpn_box_reg': 0.0712}
# Sem melhora. Patience: 6/200
# Epoch 32, Loss média: 0.3471, Boxes: 2298, Tempo: 528.1s
# Última loss breakdown: {'loss_classifier': 0.0448, 'loss_box_reg': 0.1751, 'loss_objectness': 0.0472, 'loss_rpn_box_reg': 0.0675}
# Sem melhora. Patience: 7/200
# Epoch 33, Loss média: 0.3458, Boxes: 2298, Tempo: 512.8s
# Última loss breakdown: {'loss_classifier': 0.0553, 'loss_box_reg': 0.19, 'loss_objectness': 0.0394, 'loss_rpn_box_reg': 0.0738}
# Sem melhora. Patience: 8/200
# Epoch 34, Loss média: 0.3437, Boxes: 2298, Tempo: 481.9s
# Última loss breakdown: {'loss_classifier': 0.0484, 'loss_box_reg': 0.1828, 'loss_objectness': 0.0383, 'loss_rpn_box_reg': 0.0779}
# Sem melhora. Patience: 9/200
# Epoch 35, Loss média: 0.3434, Boxes: 2298, Tempo: 497.5s
# Última loss breakdown: {'loss_classifier': 0.0369, 'loss_box_reg': 0.1723, 'loss_objectness': 0.0427, 'loss_rpn_box_reg': 0.0699}
# Sem melhora. Patience: 10/200
# Epoch 36, Loss média: 0.3435, Boxes: 2298, Tempo: 524.4s
# Última loss breakdown: {'loss_classifier': 0.0585, 'loss_box_reg': 0.1977, 'loss_objectness': 0.0475, 'loss_rpn_box_reg': 0.076}
# Sem melhora. Patience: 11/200
# Epoch 37, Loss média: 0.3453, Boxes: 2298, Tempo: 503.4s
# Última loss breakdown: {'loss_classifier': 0.0561, 'loss_box_reg': 0.1888, 'loss_objectness': 0.0412, 'loss_rpn_box_reg': 0.0714}
# Sem melhora. Patience: 12/200
# Epoch 38, Loss média: 0.3418, Boxes: 2298, Tempo: 508.9s
# Última loss breakdown: {'loss_classifier': 0.0397, 'loss_box_reg': 0.1713, 'loss_objectness': 0.0322, 'loss_rpn_box_reg': 0.0637}
# Sem melhora. Patience: 13/200
# Epoch 39, Loss média: 0.3453, Boxes: 2298, Tempo: 524.9s
# Última loss breakdown: {'loss_classifier': 0.0543, 'loss_box_reg': 0.1909, 'loss_objectness': 0.0416, 'loss_rpn_box_reg': 0.0741}
# Sem melhora. Patience: 14/200
# Epoch 40, Loss média: 0.3423, Boxes: 2298, Tempo: 536.1s
# Última loss breakdown: {'loss_classifier': 0.0481, 'loss_box_reg': 0.1775, 'loss_objectness': 0.0334, 'loss_rpn_box_reg': 0.067}
# Sem melhora. Patience: 15/200
# Epoch 41, Loss média: 0.3417, Boxes: 2298, Tempo: 496.5s
# Última loss breakdown: {'loss_classifier': 0.0445, 'loss_box_reg': 0.1793, 'loss_objectness': 0.0459, 'loss_rpn_box_reg': 0.0771}
# Sem melhora. Patience: 16/200
# Epoch 42, Loss média: 0.3406, Boxes: 2298, Tempo: 523.0s
# Última loss breakdown: {'loss_classifier': 0.0477, 'loss_box_reg': 0.1933, 'loss_objectness': 0.0325, 'loss_rpn_box_reg': 0.0788}
# Sem melhora. Patience: 17/200
# Epoch 43, Loss média: 0.3453, Boxes: 2298, Tempo: 497.9s
# Última loss breakdown: {'loss_classifier': 0.048, 'loss_box_reg': 0.18, 'loss_objectness': 0.0565, 'loss_rpn_box_reg': 0.0707}
# Sem melhora. Patience: 18/200
# Epoch 44, Loss média: 0.3495, Boxes: 2298, Tempo: 521.7s
# Última loss breakdown: {'loss_classifier': 0.0448, 'loss_box_reg': 0.1827, 'loss_objectness': 0.0362, 'loss_rpn_box_reg': 0.0724}
# Sem melhora. Patience: 19/200
# Epoch 45, Loss média: 0.3453, Boxes: 2298, Tempo: 482.9s
# Última loss breakdown: {'loss_classifier': 0.0559, 'loss_box_reg': 0.1899, 'loss_objectness': 0.0337, 'loss_rpn_box_reg': 0.0721}
# Sem melhora. Patience: 20/200
# Epoch 46, Loss média: 0.3439, Boxes: 2298, Tempo: 507.8s
# Última loss breakdown: {'loss_classifier': 0.0527, 'loss_box_reg': 0.1916, 'loss_objectness': 0.0369, 'loss_rpn_box_reg': 0.0769}
# Sem melhora. Patience: 21/200
# Epoch 47, Loss média: 0.3413, Boxes: 2298, Tempo: 491.7s
# Última loss breakdown: {'loss_classifier': 0.0537, 'loss_box_reg': 0.1966, 'loss_objectness': 0.0562, 'loss_rpn_box_reg': 0.08}
# Sem melhora. Patience: 22/200
# Epoch 48, Loss média: 0.3398, Boxes: 2298, Tempo: 490.3s
# Última loss breakdown: {'loss_classifier': 0.0472, 'loss_box_reg': 0.1846, 'loss_objectness': 0.033, 'loss_rpn_box_reg': 0.0744}
# Sem melhora. Patience: 23/200
# Epoch 49, Loss média: 0.3500, Boxes: 2298, Tempo: 492.8s
# Última loss breakdown: {'loss_classifier': 0.0623, 'loss_box_reg': 0.1922, 'loss_objectness': 0.0339, 'loss_rpn_box_reg': 0.0806}
# Sem melhora. Patience: 24/200
# Epoch 50, Loss média: 0.3415, Boxes: 2298, Tempo: 488.9s
# Última loss breakdown: {'loss_classifier': 0.0488, 'loss_box_reg': 0.1959, 'loss_objectness': 0.0294, 'loss_rpn_box_reg': 0.0731}
# Sem melhora. Patience: 25/200
# Epoch 51, Loss média: 0.3444, Boxes: 2298, Tempo: 483.1s
# Última loss breakdown: {'loss_classifier': 0.0448, 'loss_box_reg': 0.1841, 'loss_objectness': 0.0415, 'loss_rpn_box_reg': 0.0735}
# Sem melhora. Patience: 26/200
# Epoch 52, Loss média: 0.3394, Boxes: 2298, Tempo: 479.1s
# Última loss breakdown: {'loss_classifier': 0.046, 'loss_box_reg': 0.1848, 'loss_objectness': 0.0358, 'loss_rpn_box_reg': 0.0727}
# Sem melhora. Patience: 27/200
# Epoch 53, Loss média: 0.3448, Boxes: 2298, Tempo: 481.9s
# Última loss breakdown: {'loss_classifier': 0.0511, 'loss_box_reg': 0.1863, 'loss_objectness': 0.0417, 'loss_rpn_box_reg': 0.0802}
# Sem melhora. Patience: 28/200
# Epoch 54, Loss média: 0.3415, Boxes: 2298, Tempo: 487.4s
# Última loss breakdown: {'loss_classifier': 0.0419, 'loss_box_reg': 0.1662, 'loss_objectness': 0.0353, 'loss_rpn_box_reg': 0.0722}
# Sem melhora. Patience: 29/200
# Epoch 55, Loss média: 0.3450, Boxes: 2298, Tempo: 484.8s
# Última loss breakdown: {'loss_classifier': 0.0472, 'loss_box_reg': 0.1819, 'loss_objectness': 0.0524, 'loss_rpn_box_reg': 0.0782}
# Sem melhora. Patience: 30/200
# Epoch 56, Loss média: 0.3408, Boxes: 2298, Tempo: 471.7s
# Última loss breakdown: {'loss_classifier': 0.043, 'loss_box_reg': 0.177, 'loss_objectness': 0.03, 'loss_rpn_box_reg': 0.0652}
# Sem melhora. Patience: 31/200
# Epoch 57, Loss média: 0.3438, Boxes: 2298, Tempo: 483.3s
# Última loss breakdown: {'loss_classifier': 0.0519, 'loss_box_reg': 0.2063, 'loss_objectness': 0.0382, 'loss_rpn_box_reg': 0.0701}
# Sem melhora. Patience: 32/200
# Epoch 58, Loss média: 0.3427, Boxes: 2298, Tempo: 493.2s
# Última loss breakdown: {'loss_classifier': 0.0488, 'loss_box_reg': 0.1757, 'loss_objectness': 0.0412, 'loss_rpn_box_reg': 0.0701}
# Sem melhora. Patience: 33/200
# Epoch 59, Loss média: 0.3467, Boxes: 2298, Tempo: 491.0s
# Última loss breakdown: {'loss_classifier': 0.0491, 'loss_box_reg': 0.181, 'loss_objectness': 0.0425, 'loss_rpn_box_reg': 0.0705}
# Sem melhora. Patience: 34/200
# Epoch 60, Loss média: 0.3432, Boxes: 2298, Tempo: 501.6s
# Última loss breakdown: {'loss_classifier': 0.0461, 'loss_box_reg': 0.1903, 'loss_objectness': 0.0343, 'loss_rpn_box_reg': 0.0762}
# Sem melhora. Patience: 35/200
# Epoch 61, Loss média: 0.3414, Boxes: 2298, Tempo: 478.4s
# Última loss breakdown: {'loss_classifier': 0.0498, 'loss_box_reg': 0.1808, 'loss_objectness': 0.0402, 'loss_rpn_box_reg': 0.0725}
# Sem melhora. Patience: 36/200
# Epoch 62, Loss média: 0.3446, Boxes: 2298, Tempo: 475.6s
# Última loss breakdown: {'loss_classifier': 0.0488, 'loss_box_reg': 0.1783, 'loss_objectness': 0.0515, 'loss_rpn_box_reg': 0.0764}
# Sem melhora. Patience: 37/200
# Epoch 63, Loss média: 0.3436, Boxes: 2298, Tempo: 483.1s
# Última loss breakdown: {'loss_classifier': 0.0614, 'loss_box_reg': 0.189, 'loss_objectness': 0.0258, 'loss_rpn_box_reg': 0.0713}
# Sem melhora. Patience: 38/200
# Epoch 64, Loss média: 0.3434, Boxes: 2298, Tempo: 459.1s
# Última loss breakdown: {'loss_classifier': 0.0398, 'loss_box_reg': 0.1785, 'loss_objectness': 0.0367, 'loss_rpn_box_reg': 0.0743}
# Sem melhora. Patience: 39/200
# Epoch 65, Loss média: 0.3417, Boxes: 2298, Tempo: 477.1s
# Última loss breakdown: {'loss_classifier': 0.0503, 'loss_box_reg': 0.182, 'loss_objectness': 0.0298, 'loss_rpn_box_reg': 0.0749}
# Sem melhora. Patience: 40/200
# Epoch 66, Loss média: 0.3468, Boxes: 2298, Tempo: 481.1s
# Última loss breakdown: {'loss_classifier': 0.0439, 'loss_box_reg': 0.1841, 'loss_objectness': 0.0399, 'loss_rpn_box_reg': 0.0738}
# Sem melhora. Patience: 41/200
# Epoch 67, Loss média: 0.3381, Boxes: 2298, Tempo: 478.8s
# Última loss breakdown: {'loss_classifier': 0.0509, 'loss_box_reg': 0.1804, 'loss_objectness': 0.0312, 'loss_rpn_box_reg': 0.074}
# Sem melhora. Patience: 42/200
# Epoch 68, Loss média: 0.3456, Boxes: 2298, Tempo: 466.8s
# Última loss breakdown: {'loss_classifier': 0.0556, 'loss_box_reg': 0.2, 'loss_objectness': 0.0522, 'loss_rpn_box_reg': 0.0703}
# Sem melhora. Patience: 43/200
# Epoch 69, Loss média: 0.3382, Boxes: 2298, Tempo: 480.1s
# Última loss breakdown: {'loss_classifier': 0.0572, 'loss_box_reg': 0.1955, 'loss_objectness': 0.0221, 'loss_rpn_box_reg': 0.0713}
# Sem melhora. Patience: 44/200
# Epoch 70, Loss média: 0.3396, Boxes: 2298, Tempo: 484.6s
# Última loss breakdown: {'loss_classifier': 0.0404, 'loss_box_reg': 0.1731, 'loss_objectness': 0.0253, 'loss_rpn_box_reg': 0.0713}
# Sem melhora. Patience: 45/200
# Epoch 71, Loss média: 0.3430, Boxes: 2298, Tempo: 481.7s
# Última loss breakdown: {'loss_classifier': 0.0391, 'loss_box_reg': 0.1825, 'loss_objectness': 0.0452, 'loss_rpn_box_reg': 0.0701}
# Sem melhora. Patience: 46/200
# Epoch 72, Loss média: 0.3459, Boxes: 2298, Tempo: 506.4s
# Última loss breakdown: {'loss_classifier': 0.0562, 'loss_box_reg': 0.2037, 'loss_objectness': 0.0423, 'loss_rpn_box_reg': 0.0772}
# Sem melhora. Patience: 47/200
# Epoch 73, Loss média: 0.3449, Boxes: 2298, Tempo: 501.5s
# Última loss breakdown: {'loss_classifier': 0.0532, 'loss_box_reg': 0.1969, 'loss_objectness': 0.0379, 'loss_rpn_box_reg': 0.0648}
# Sem melhora. Patience: 48/200
# Epoch 74, Loss média: 0.3381, Boxes: 2298, Tempo: 493.2s
# Última loss breakdown: {'loss_classifier': 0.0504, 'loss_box_reg': 0.1913, 'loss_objectness': 0.036, 'loss_rpn_box_reg': 0.0745}
# Sem melhora. Patience: 49/200
# Epoch 75, Loss média: 0.3446, Boxes: 2298, Tempo: 476.4s
# Última loss breakdown: {'loss_classifier': 0.0459, 'loss_box_reg': 0.178, 'loss_objectness': 0.0332, 'loss_rpn_box_reg': 0.081}
# Sem melhora. Patience: 50/200
# Epoch 76, Loss média: 0.3422, Boxes: 2298, Tempo: 475.4s
# Última loss breakdown: {'loss_classifier': 0.0546, 'loss_box_reg': 0.2015, 'loss_objectness': 0.04, 'loss_rpn_box_reg': 0.0758}
# Sem melhora. Patience: 51/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 29
#      26 timestamp = datetime.now().strftime('%Y%m%d_%H%M%S') # Obter o timestamp atual para nomear o modelo
#      27 save_path = os.path.join(save_dir,  f'best_faster_rcnn_model_{timestamp}.pth')
# ---> 29 run_train_novo(device, model, data_loader, optimizer, num_epochs, save_path)
#
# Cell In[29], line 163, in run_train_novo(device, model, data_loader, optimizer, num_epochs, save_path)
#     157         processed_targets.append({
#     158             'boxes': torch.empty((0, 4), device=device),
#     159             'labels': torch.empty((0,), dtype=torch.int64, device=device)
#     160         })
#     162 if any(len(pt['boxes']) > 0 for pt in processed_targets):
# --> 163     loss_dict = model(images, processed_targets)
#     164     losses = sum(loss for loss in loss_dict.values())
#     165     total_loss += losses.item()
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torchvision\models\detection\generalized_rcnn.py:104, in GeneralizedRCNN.forward(self, images, targets)
#     102 if isinstance(features, torch.Tensor):
#     103     features = OrderedDict([("0", features)])
# --> 104 proposals, proposal_losses = self.rpn(images, features, targets)
#     105 detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#     106 detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)  # type: ignore[operator]
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torchvision\models\detection\rpn.py:371, in RegionProposalNetwork.forward(self, images, features, targets)
#     367 objectness, pred_bbox_deltas = concat_box_prediction_layers(objectness, pred_bbox_deltas)
#     368 # apply pred_bbox_deltas to anchors to obtain the decoded proposals
#     369 # note that we detach the deltas because Faster R-CNN do not backprop through
#     370 # the proposals
# --> 371 proposals = self.box_coder.decode(pred_bbox_deltas.detach(), anchors)
#     372 proposals = proposals.view(num_images, -1, 4)
#     373 boxes, scores = self.filter_proposals(proposals, objectness, images.image_sizes, num_anchors_per_level)
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torchvision\models\detection\_utils.py:178, in BoxCoder.decode(self, rel_codes, boxes)
#     176 if box_sum > 0:
#     177     rel_codes = rel_codes.reshape(box_sum, -1)
# --> 178 pred_boxes = self.decode_single(rel_codes, concat_boxes)
#     179 if box_sum > 0:
#     180     pred_boxes = pred_boxes.reshape(box_sum, -1, 4)
#
# File c:\ProjetosPython\PICOS\.venv\lib\site-packages\torchvision\models\detection\_utils.py:216, in BoxCoder.decode_single(self, rel_codes, boxes)
#     213 pred_h = torch.exp(dh) * heights[:, None]
#     215 # Distance from center to box's corner.
# --> 216 c_to_c_h = torch.tensor(0.5, dtype=pred_ctr_y.dtype, device=pred_h.device) * pred_h
#     217 c_to_c_w = torch.tensor(0.5, dtype=pred_ctr_x.dtype, device=pred_w.device) * pred_w
#     219 pred_boxes1 = pred_ctr_x - c_to_c_w
#
# KeyboardInterrupt:

# %% [markdown]
# ### 4.2.2 Test Model

# %%
# Iniciar
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Definir o dispositivo (GPU ou CPU)

# Inputs
images_dir = r'data/inputs/train_images/COCO_20250604/train' 
annotations_path = r'data/inputs/train_images/COCO_20250604/train/_annotations.coco.json' 
save_dir = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
models_path = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
pretrained_model_path = os.path.join(models_path, 'best_faster_rcnn_model_20250326_154439.pth')  # Altere para o caminho do modelo salvo (ex: 'caminho/para/modelo.pth') ou mantenha None para treinar do zero
weights='FasterRCNN_ResNet50_FPN_Weights.COCO_V1'
num_classes = 2  # Inclua o número de classes (background + classes)
num_epochs = 10000
data_loader_batch_size = 1

#  Main
model = create_model(weights, num_classes)
model = load_pretrained_model(device, model, pretrained_model_path)
model = load_model_eval(device, model, pretrained_model_path)
test_dataset, test_data_loader = dataset_config(images_dir, annotations_path, data_loader_batch_size)

print(f"Modelo no modo de avaliação no dispositivo: {next(model.parameters()).device}") # Verificar se o modelo está no dispositivo correto (GPU ou CPU)

# Caminho da imagem que você deseja testar
image_path = r'/home/mdb/ProjetosPython/Picos_pip/data/inputs/test_images/Imagem0001 - 25.jpg'  # Substitua pelo caminho da sua imagem
image_tensor = load_image_tensor(image_path)

visualize_predictions_image(device, model, image_tensor, threshold=0.5)

# %% [markdown]
# ## 4.3 ONNX

# %% [markdown]
# ### 4.3.1 Convert to ONNX

# %%
# Iniciar
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Definir o dispositivo (GPU ou CPU)

# Inputs
images_dir = os.path.join(base_dir, r'data/inputs/train_images/COCO_20250604/train') 
annotations_path =  r'data/inputs/train_images/COCO_20250604/train/_annotations.coco.json'
save_dir = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
models_path = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
pretrained_model_path = os.path.join(models_path, 'best_faster_rcnn_model_20250326_154439.pth')  # Altere para o caminho do modelo salvo (ex: 'caminho/para/modelo.pth') ou mantenha None para treinar do zero
weights='FasterRCNN_ResNet50_FPN_Weights.COCO_V1'
num_classes = 2  # Inclua o número de classes (background + classes)
data_loader_batch_size = 8
num_epochs = 10000

model = create_model(weights, num_classes)
model = load_pretrained_model(device, model, pretrained_model_path)
model = load_model_eval(device, model, pretrained_model_path)
dataset, data_loader = dataset_config(images_dir, annotations_path, data_loader_batch_size)

dummy_input = torch.randn(1, 3, 640, 640, device=device) # Criar um tensor de entrada simulado (1 imagem com 3 canais, 640x640)

model_onnx_path = os.path.join(models_path,  f'{os.path.splitext(os.path.basename(pretrained_model_path))[0]}.onnx') # Nome do arquivo ONNX

# Exportar o modelo para ONNX
torch.onnx.export(
    model,                          # Modelo treinado
    dummy_input,                    # Entrada simulada
    model_onnx_path,                       # Nome do arquivo de saída
    opset_version=11,                # Versão do conjunto de operações ONNX
    input_names=["input"],           # Nome da entrada
    output_names=["boxes", "labels", "scores"],  # Nomes das saídas
    dynamic_axes={"input": {0: "batch_size"},   # Permite entradas de diferentes tamanhos
                  "boxes": {0: "batch_size"},
                  "labels": {0: "batch_size"},
                  "scores": {0: "batch_size"}}
)

print(f"Modelo convertido para ONNX e salvo como '{model_onnx_path}'.")

# %% [markdown]
# ### 4.3.2 Test Model

# %%
# Iniciar
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Definir o dispositivo (GPU ou CPU)

# Inputs
images_dir = os.path.join(base_dir, r'data/inputs/train_images/COCO_20250604/train') 
annotations_path =  r'data/inputs/train_images/COCO_20250604/train/_annotations.coco.json'
save_dir = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
models_path = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
model_onnx_path = os.path.join(models_path, 'best_faster_rcnn_model_20250326_154439.onnx')  # Altere para o caminho do modelo salvo (ex: 'caminho/para/modelo.pth') ou mantenha None para treinar do zero
weights='FasterRCNN_ResNet50_FPN_Weights.COCO_V1'
num_classes = 2  # Inclua o número de classes (background + classes)
data_loader_batch_size = 8
num_epochs = 10000

jpg_files = [f for f in os.listdir(images_dir) if f.lower().endswith('.jpg')]
image_path = os.path.join(images_dir, jpg_files[0]) # Primeira Imagem
image_tensor = load_image_tensor(image_path)
ort_session = load_onnx_model(device, model_onnx_path)
outputs = visualize_predictions_onnx(device, ort_session, image_tensor, threshold=0.5)

# %% [markdown]
# # 4.4 Convert to TensorRT

# %%
# Inputs
images_dir = os.path.join(base_dir, r'data/inputs/train_images/COCO_20250604/train') 
annotations_path =  r'data/inputs/train_images/COCO_20250604/train/_annotations.coco.json'
save_dir = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
models_path = os.path.join(base_dir, 'data', 'inputs', 'ia_models', 'FRCNN Resnet50')
model_model_onnx_path = os.path.join(models_path, 'best_faster_rcnn_model_20250326_154439.onnx')  # Altere para o caminho do modelo salvo (ex: 'caminho/para/modelo.pth') ou mantenha None para treinar do zero
weights='FasterRCNN_ResNet50_FPN_Weights.COCO_V1'
num_classes = 2  # Inclua o número de classes (background + classes)
data_loader_batch_size = 8
num_epochs = 10000


# Carregar o modelo ONNX
onnx_model = onnx.load(model_onnx_path)

# Verificar se há erros
onnx.checker.check_model(onnx_model)
print("Modelo ONNX é válido!")

# Testar inferência com ONNX Runtime
ort_session = ort.InferenceSession(model_onnx_path)
outputs = ort_session.run(None, {"input": dummy_input.cpu().numpy()})

print("Inferência ONNX concluída com sucesso!")

# Converter ONNX para TensorRT
TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
builder = trt.Builder(TRT_LOGGER)
network = builder.create_network(1)
parser = trt.OnnxParser(network, TRT_LOGGER)

with open(model_onnx_path, 'rb') as model_file:
    if not parser.parse(model_file.read()):
        print("Falha ao analisar o modelo ONNX!")
        for error in range(parser.num_errors):
            print(parser.get_error(error))
        exit()

config = builder.create_builder_config()
config.max_workspace_size = 1 << 30  # 1GB
engine = builder.build_engine(network, config)

# Salvar o modelo TensorRT
trt_engine_path = "faster_rcnn_resnet50.trt"
with open(trt_engine_path, "wb") as f:
    f.write(engine.serialize())

print(f"Modelo convertido para TensorRT e salvo como '{trt_engine_path}'.")
