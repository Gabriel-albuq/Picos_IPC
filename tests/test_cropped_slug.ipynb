# %%
import cv2
import numpy as np
import sys
import os

base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(base_dir)

sys.path.append(base_dir)

def cropped_generate(input_dir, output_dir):
    # Carrega a imagem
    nome_arquivo = os.path.basename(input_dir)  
    nome_sem_extensao = os.path.splitext(nome_arquivo)[0]
    imagem = cv2.imread(input_dir)

    # Converte para HSV
    hsv = cv2.cvtColor(imagem, cv2.COLOR_BGR2HSV)

    # Intervalo para tons de marrom
    limite_inferior = np.array([10, 100, 20])
    limite_superior = np.array([20, 255, 200])
    mascara_marrom = cv2.inRange(hsv, limite_inferior, limite_superior)

    # Encontrar contornos
    contornos, _ = cv2.findContours(mascara_marrom, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Cópia da imagem original
    imagem_quadrados = imagem.copy()
    altura, largura = imagem.shape[:2]

    padding = 20
    margem_borda = 10
    contador = 1

    for contorno in contornos:
        area = cv2.contourArea(contorno)
        x, y, w, h = cv2.boundingRect(contorno)
        if area > 500 and w > 150:
            contador += 1
            lado = max(w, h)
            centro_x = x + w // 2
            centro_y = y + h // 2
            novo_x = centro_x - lado // 2
            novo_y = centro_y - lado // 2

            # Ajusta com padding e mantém dentro da imagem
            novo_x_pad = max(novo_x - padding, 0)
            novo_y_pad = max(novo_y - padding, 0)
            fim_x_pad = min(novo_x + lado + padding, largura)
            fim_y_pad = min(novo_y + lado + padding, altura)

            # Verifica se está pelo menos a margem_borda pixels da borda da imagem
            if (novo_x_pad < margem_borda or novo_y_pad < margem_borda or
                fim_x_pad > largura - margem_borda or fim_y_pad > altura - margem_borda):
                # Ignora esta região, não desenha nem gera imagem
                continue

            lado_pad = min(fim_x_pad - novo_x_pad, fim_y_pad - novo_y_pad)

            # Marcar Imagem
            # cv2.rectangle(imagem_quadrados, 
            #               (novo_x, novo_y), (novo_x + lado, novo_y + lado), 
            #               (255, 0, 0), 
            #               2
            # ) # Desenhar o quadrado original (sem padding) - opcional

            
            # cv2.rectangle(imagem_quadrados, 
            #               (novo_x_pad, novo_y_pad), (novo_x_pad + lado_pad, novo_y_pad + lado_pad), 
            #               (0, 255, 0), 
            #               2
            # ) # Desenhar o quadrado com padding - opcional (em verde)

            # Redimensionar para 640x640
            recorte = imagem[novo_y_pad:novo_y_pad + lado_pad, novo_x_pad:novo_x_pad + lado_pad]
            imagem_expandidada = cv2.resize(recorte, (640, 640), interpolation=cv2.INTER_LINEAR)

            # Salvar a imagem expandida
            caminho_salvar = os.path.join(output_dir, f'{nome_sem_extensao}_cropped_{contador}.jpg')
            cv2.imwrite(caminho_salvar, imagem_expandidada)

            # Mostrar cada imagem expandida numa janela separada
            # cv2.imshow(f'Marcacao {contador}', imagem_expandidada)

    # Mostrar a imagem com quadrados desenhados
    #cv2.imshow('Quadrados Perfeitos em Áreas Marrons com Padding', imagem_quadrados)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
# Out:
# c:\Projetos Python\PICOS

# %%
input_dir = os.path.join(base_dir, 'data', 'inputs', 'train_images', 'ImagensOriginais_gx')
output_dir = os.path.join(base_dir, 'data', 'outputs', 'cropped_generate')

# Criar pasta de saída caso não exista
os.makedirs(output_dir, exist_ok=True)

# Listar arquivos .jpg na pasta de entrada
for arquivo in os.listdir(input_dir):
    if arquivo.lower().endswith('.jpg'):
        caminho_arquivo = os.path.join(input_dir, arquivo)
        print(f'Processando: {arquivo}')
        cropped_generate(caminho_arquivo, output_dir)

print('Processamento finalizado.')
# Out:
# Processando: frame_0000_jpg.rf.9b2af89e627eea5f5a779144f0d76e86.jpg
# Processando: frame_0001_jpg.rf.e4000e53bf8873b6ca2e0c4e09cff4f3.jpg
# Processando: frame_0002_jpg.rf.0514e1c7d3d85266715ff9413f24c596.jpg
# Processando: frame_0003_jpg.rf.8d3beeceaec715b2641202ad4c2e8839.jpg
# Processando: frame_0004_jpg.rf.f71bfeca21d37112935badc8b9d105a0.jpg
# Processando: frame_0005_jpg.rf.4afcabaae4949f53c1a4e070f1491f62.jpg
# Processando: frame_0006_jpg.rf.f8eb4ed00ae15d48b1fa21b6b64eebd9.jpg
# Processando: frame_0007_jpg.rf.2cd6464267989262f93b44c7a35af69e.jpg
# Processando: frame_0008_jpg.rf.aae5bf226e7add8c85222c8b1df9ded8.jpg
# Processando: frame_0009_jpg.rf.acfa8d792f2a0780811e099e6133022e.jpg
# Processando: frame_0010_jpg.rf.050cb3448cdd6d4fafbc89af32609f40.jpg
# Processando: frame_0011_jpg.rf.fb9ab867b52cd3623a0aca6e696628bf.jpg
# Processando: frame_0012_jpg.rf.1787fe3942a9d645266f0fd764308068.jpg
# Processando: frame_0013_jpg.rf.6778b88fd08615b50daa42bb32d3b8c8.jpg
# Processando: frame_0014_jpg.rf.cbe8016368c98403ad2c25a068a333ab.jpg
# Processando: frame_0015_jpg.rf.87bcb79225172c46d94fbcd46898ec19.jpg
# Processando: frame_0016_jpg.rf.7de6a6c0b7eb17525531b6ccf35387a5.jpg
# Processando: frame_0017_jpg.rf.4caae00ad2fc03cf784a5e1a7f02930e.jpg
# Processando: frame_0018_jpg.rf.073cb5bcd074d824b69b754cfccf7d94.jpg
# Processando: frame_0019_jpg.rf.b51bf629ca5b7fe3588e8e552bbd010b.jpg
# Processando: frame_0020_jpg.rf.39023518d6f02cb73997c78173726285.jpg
# Processando: frame_0021_jpg.rf.8b56a9580165ecd997291172cb8ad695.jpg
# Processando: frame_0022_jpg.rf.721f8d2c5bfb467a9d4838dab4220705.jpg
# Processando: frame_0023_jpg.rf.073f984eee397ddda037d26570c27652.jpg
# Processando: frame_0024_jpg.rf.a933a020961961e059ddebdb192bf8e7.jpg
# Processando: frame_0025_jpg.rf.79519f5785e15ce0d18832bd3d0e6fa1.jpg
# Processando: frame_0026_jpg.rf.72574dbfbaa6d5fc721ae94cb9eb73b3.jpg
# Processando: frame_0027_jpg.rf.521bf62f39a02e11e89c30ed80fb221a.jpg
# Processando: frame_0028_jpg.rf.21f58dae27bbd698a7dbc27edfa9f1d4.jpg
# Processando: frame_0029_jpg.rf.f280a3ffefbd2ebdec65b6a3a3eaa2c2.jpg
# Processando: frame_0030_jpg.rf.41d8b1b0b03546ede93561dbaf871dde.jpg
# Processando: frame_0031_jpg.rf.24862dccd740cd8a34cee3bada527fca.jpg
# Processando: frame_0032_jpg.rf.340f72ed85ad81336889743a4e71026c.jpg
# Processando: frame_0033_jpg.rf.bfa15ef21eb39e93b0e83c3aef16eaaf.jpg
# Processando: frame_0034_jpg.rf.24fea1c8b77a1abb6e3a45f097ce0eae.jpg
# Processando: frame_0035_jpg.rf.43a29e6b96a5fdf1648eadd0a380d2a5.jpg
# Processando: frame_0036_jpg.rf.c00bcc8bc64db4149f8dff459e3d10c2.jpg
# Processando: frame_0037_jpg.rf.89e8306aec78e44707c61586d93fcfa4.jpg
# Processando: frame_0038_jpg.rf.9fba82ce62819857a4e58c02bfc6bd27.jpg
# Processando: frame_0039_jpg.rf.a21119c2e9019dbb51b10036e5d96741.jpg
# Processando: frame_0040_jpg.rf.9c66818b8860240957511631370d2e26.jpg
# Processando: frame_0041_jpg.rf.71fa88e7f5746736bca830db7e00be48.jpg
# Processando: frame_0042_jpg.rf.5b645b96666efe70c1fb7f7e5047ad8c.jpg
# Processando: frame_0043_jpg.rf.2b2c88be8d76e6ed45b0d2b04c0ca540.jpg
# Processando: frame_0044_jpg.rf.efcf064e1cfa9a7503f9143a3d8cc3b9.jpg
# Processando: frame_0045_jpg.rf.539b09a8469798b47f920b7d2d2c2816.jpg
# Processando: frame_0046_jpg.rf.250918d4b76793d8f380aa6cce119b5f.jpg
# Processando: frame_0047_jpg.rf.3e4db0c8c4721a505a2a973c6ae8551e.jpg
# Processando: frame_0048_jpg.rf.e1d07da3f65fa539b00ffc63e8d9b9b4.jpg
# Processando: frame_0049_jpg.rf.01055745f5a04b958a8bf37a63732962.jpg
# Processando: frame_0050_jpg.rf.fcd414f9906c266f9b94e4f461419992.jpg
# Processando: frame_0051_jpg.rf.b1f92aedd8819226cd5540a750747d81.jpg
# Processando: frame_0052_jpg.rf.c2f9d90bd502bf645cc9aeb6458fa63f.jpg
# Processando: frame_0053_jpg.rf.98b836f0cd997af80022474751f001ae.jpg
# Processando: frame_0054_jpg.rf.fe94a8b1069522c9fb04acd713160fe9.jpg
# Processando: frame_0055_jpg.rf.5242e7bce2cc465bf818b6fa325b15b8.jpg
# Processando: frame_0056_jpg.rf.d16407c8a5be81d60810280db8cc2855.jpg
# Processando: frame_0057_jpg.rf.56f8b7229714a869124ee63e62242583.jpg
# Processando: frame_0058_jpg.rf.ce8a9dd8f4ae3cc946eaecb0d2f2c8e9.jpg
# Processando: frame_0059_jpg.rf.c9592c3400a4dca11c8ce9fdb1b3791f.jpg
# Processando: frame_0060_jpg.rf.713adc578e57a205d3bc9706a881e379.jpg
# Processando: frame_0061_jpg.rf.4611d8db411c2d69650b6fd25fad01ea.jpg
# Processando: frame_0062_jpg.rf.622734da70b0794c585a6728483f4306.jpg
# Processando: frame_0063_jpg.rf.63935300ceb2e3644096988e70c3c11b.jpg
# Processando: frame_0064_jpg.rf.57e2d56e1e453fbf8e6b5ec2eb012f6d.jpg
# Processando: frame_0065_jpg.rf.41159e435d89558f0a59e5090ded5e13.jpg
# Processando: frame_0066_jpg.rf.ce25f13329f359d3249c9f9584c8704f.jpg
# Processando: frame_0067_jpg.rf.c23d3c09f839b2d99ccd4f3813fe2944.jpg
# Processando: frame_0068_jpg.rf.a21c0a9e15f87f00a3359f05d1fba781.jpg
# Processando: frame_0069_jpg.rf.c1a185b4b8988c4214b986a7ee8c31c9.jpg
# Processando: frame_0070_jpg.rf.ee1d679e7416bf26e103bc46dcf4ecd8.jpg
# Processando: frame_0071_jpg.rf.dea0c3da53eaf69ad964bfa10cce4be7.jpg
# Processando: frame_0072_jpg.rf.8eb24c790318a896cd451a629e7a1c9b.jpg
# Processando: frame_0073_jpg.rf.988fc20ed9967caae2ac44b4d00f85bc.jpg
# Processando: frame_0074_jpg.rf.810f221417eafebfa64e98b40bee2a42.jpg
# Processando: frame_0075_jpg.rf.9ddbb03d42e41358ca8a28c271d9b94d.jpg
# Processando: frame_0076_jpg.rf.cf72fcc8ed8994deda5263217e5ce8bb.jpg
# Processando: frame_0077_jpg.rf.07c0cab3127ecdb79047a64ed5e5aee2.jpg
# Processando: frame_0078_jpg.rf.e92d0f588d5dc04aa28210d40d94d6a1.jpg
# Processando: frame_0079_jpg.rf.22fb8eb91b99059960aa1055347e98aa.jpg
# Processando: frame_0080_jpg.rf.c3a48601500ebaba977356de7b948695.jpg
# Processando: frame_0081_jpg.rf.c64927245410d133662b091bb34f3f25.jpg
# Processando: frame_0082_jpg.rf.d9b8a335ee40283c1ee8c97e94592b23.jpg
# Processando: frame_0083_jpg.rf.6a319b2015edd5b0d883fbee9102cf89.jpg
# Processando: frame_0084_jpg.rf.51de2c756eaaca914879a38d92f7d1c7.jpg
# Processando: frame_0085_jpg.rf.91a248282fe747e1c85f9d5b045a789e.jpg
# Processando: frame_0086_jpg.rf.1dfb66cb93ce8674728dffa4e07c94d3.jpg
# Processando: frame_0087_jpg.rf.77be4832027617a68de491374b64420c.jpg
# Processando: frame_0088_jpg.rf.5e4ce7feca4f33063f7cb2f3fce2286e.jpg
# Processando: frame_0089_jpg.rf.afbfb84a4bef4929dbff466ecab24e2a.jpg
# Processando: frame_0090_jpg.rf.9ffab04e50f6b5ed1c2fcc0a46408e20.jpg
# Processando: frame_0091_jpg.rf.a54b45353aaee9df753f9767b431e2d9.jpg
# Processando: frame_0092_jpg.rf.1056974330b8baa5ed94b0bdb3cb8371.jpg
# Processando: frame_0093_jpg.rf.a6df944b2c60d8e0d8e8eaf98f12ad06.jpg
# Processando: frame_0094_jpg.rf.9b7693578e01c45714b9fd431122df3c.jpg
# Processando: frame_0095_jpg.rf.e1b14e68b4bc587fda194cefeedc3fa3.jpg
# Processando: frame_0096_jpg.rf.d75a9a230ba49c78309af554268b69a8.jpg
# Processando: frame_0097_jpg.rf.7e78163c9c26d749bdebf095efdaf9fa.jpg
# Processando: frame_0098_jpg.rf.9b46284daec8d02ef6086a4faaa28607.jpg
# Processando: frame_0099_jpg.rf.2fe9079e0bd1dfb7fc9fa39eb9fbf1eb.jpg
# Processando: frame_0100_jpg.rf.5ef1ac1722b965e94409231d311cfeb7.jpg
# Processando: frame_0101_jpg.rf.05f3f5d2d5a359ea9bd50ff76b3109ee.jpg
# Processando: frame_0102_jpg.rf.a81aa631b57a423fa9a81616ec5257cc.jpg
# Processando: frame_0103_jpg.rf.417947112a0fa6072b9fcbe387b10918.jpg
# Processando: frame_0104_jpg.rf.14b34dee4af026545c3679a45aa741a1.jpg
# Processando: frame_0105_jpg.rf.b39bd85d5117c728ded68379e21b5d9c.jpg
# Processando: frame_0106_jpg.rf.5d8f2a189bfb77407d69a58136531061.jpg
# Processando: frame_0107_jpg.rf.673d529cc45e0a0f38daa9094bf1d536.jpg
# Processando: frame_0108_jpg.rf.e46338fe920358f351996edb618bb1a8.jpg
# Processando: frame_0109_jpg.rf.cc5169c6ef85f48f0ae61b53aae78a1e.jpg
# Processando: frame_0110_jpg.rf.541a27c023838c72f50a833f93c0d254.jpg
# Processando: frame_0111_jpg.rf.6b7b66073f1b06b628b3497a5f5c1454.jpg
# Processando: frame_0112_jpg.rf.3aae02302ae1ecdf837c76e22bf4bdb4.jpg
# Processando: frame_0113_jpg.rf.4abb297d926b2aa6157a19e0fd21b6ce.jpg
# Processando: frame_0114_jpg.rf.1116b2ba98631b9c9bcf0a6b20963bc2.jpg
# Processando: frame_0115_jpg.rf.f5ae224c7be1007b9d2314cc25cead6f.jpg
# Processando: frame_0116_jpg.rf.f630ec701fd03283f6cdc8799e3e47ff.jpg
# Processando: frame_0117_jpg.rf.58cb3e3dbcbb2ed0cb404acce9c0fe4b.jpg
# Processando: frame_0118_jpg.rf.bf80a1192cc2e23335eddfd76a14c9ec.jpg
# Processando: frame_0119_jpg.rf.fb3e14f469fc44a3888a1051d9d238e3.jpg
# Processando: frame_0120_jpg.rf.0c84de4a4c4eacc81ee1a34d572a56ac.jpg
# Processando: frame_0121_jpg.rf.c17a85a7a83f4d00407b772d1bcbc778.jpg
# Processando: frame_0122_jpg.rf.f42fed7397d1243819e4cd2461621af4.jpg
# Processando: frame_0123_jpg.rf.5c2080f6890e6ffc104c4f62ea7dbb86.jpg
# Processando: frame_0124_jpg.rf.2789b7be0a7705789aea8e9e33318d82.jpg
# Processando: frame_0125_jpg.rf.1f0598ce677d17ae9220cc5e73bf9b5f.jpg
# Processando: frame_0126_jpg.rf.a6a503a04e5452c0b650aee4ebce8864.jpg
# Processando: frame_0127_jpg.rf.b40a7a136460caf8a293b346bd9e29df.jpg
# Processando: frame_0128_jpg.rf.3fc6cc9520e7001dae855057b42a8f49.jpg
# Processando: frame_0129_jpg.rf.63157da1351217e83e492c85d4eaa559.jpg
# Processando: frame_0130_jpg.rf.b7fded0d8f463c22dad5b75fbc59577c.jpg
# Processando: frame_0131_jpg.rf.eca999ebb1655344e931fcdce3cb5c54.jpg
# Processando: frame_0132_jpg.rf.02c9cf45287cd810f31cd4429960816c.jpg
# Processando: frame_0133_jpg.rf.82cc12e3c7cf98cbab36c2e3fd997773.jpg
# Processando: frame_0134_jpg.rf.e802814af6f120c9e4e1bfff3abd0fb9.jpg
# Processando: frame_0135_jpg.rf.3d836593ecc8376e1a33d0eb988166b8.jpg
# Processando: frame_0136_jpg.rf.3bf70c0b2aa9d4bb0bcd8bb77ec4e0c1.jpg
# Processando: frame_0137_jpg.rf.b0970b978d22bf94c3c8650cebad6744.jpg
# Processando: frame_0138_jpg.rf.2800626205a31773a4ea8c117b8f2c6f.jpg
# Processando: frame_0139_jpg.rf.0ddcdb519f36b0d9669cba666afc25c3.jpg
# Processando: frame_0140_jpg.rf.09be7940ba8f2df738d907f2e4cd6031.jpg
# Processando: frame_0141_jpg.rf.985351570c1dea5b7e50a18c3b62d4c8.jpg
# Processando: frame_0142_jpg.rf.b675d6b1475dc2be5903f858c4dbd574.jpg
# Processando: frame_0143_jpg.rf.2222ba692e29f488b6b99f0f529e6000.jpg
# Processando: frame_0144_jpg.rf.f4fabc92ab9f7d70ec89209830d3b083.jpg
# Processando: frame_0145_jpg.rf.866eca50544c0c2bf93acf1ced433872.jpg
# Processando: frame_0146_jpg.rf.4f93672fcf441aa13e5168e382f9dbdf.jpg
# Processando: frame_0147_jpg.rf.fabd68cdff5dd5a744d581e5b94e90e5.jpg
# Processando: frame_0148_jpg.rf.696e45b8e9dbf011ff6b485a6ef777b0.jpg
# Processando: frame_0149_jpg.rf.98052c3b210c6bb374554fdbb0731a8a.jpg
# Processando: frame_0150_jpg.rf.4adc47ef8729ca621f0c8ac2d664fccd.jpg
# Processando: frame_0151_jpg.rf.b82271e39f5ab5c166041d16da0e96a4.jpg
# Processando: frame_0152_jpg.rf.a98185f8cde280ab50fe6ddd2279e232.jpg
# Processando: frame_0153_jpg.rf.0d1c4487d3ed40c1643825379b60a1cc.jpg
# Processando: frame_0154_jpg.rf.195445313c02f6ccae8c1e71e5a023da.jpg
# Processando: frame_0155_jpg.rf.910b964a21a56bc1e412f03c3812406d.jpg
# Processando: frame_0156_jpg.rf.36e0446ad7ed50dec1b362d67833a90e.jpg
# Processando: frame_0157_jpg.rf.69b45670d2cb829446170e32175dd6f8.jpg
# Processando: frame_0158_jpg.rf.c74aaf67e37f8dd89fe77a75264d0cdc.jpg
# Processando: frame_0159_jpg.rf.dacd07d0c5610eeaf039f48612f7483e.jpg
# Processando: frame_0160_jpg.rf.6e085299e9d50259f9f55c28632f029b.jpg
# Processando: frame_0161_jpg.rf.9a676a58c8dff435f2db48b9003af6c8.jpg
# Processando: frame_0162_jpg.rf.cf75a16ce35e331e7ea4c8ed889e9bb3.jpg
# Processando: frame_0163_jpg.rf.0dd83f3f276a16539fce4a808041d790.jpg
# Processando: frame_0164_jpg.rf.b45af76c36cd7d4d252d9943075b76bb.jpg
# Processando: frame_0165_jpg.rf.66085eaf1d79131d8dc4f8b3dff31635.jpg
# Processando: frame_0166_jpg.rf.6ed89f35d8ffeefa0e2e0e76c87a92bf.jpg
# Processando: frame_0167_jpg.rf.7b0320ebd118e3708f451d209a4d6fad.jpg
# Processando: frame_0168_jpg.rf.9b2605a0a244c7d9a019f32ea654fc3a.jpg
# Processando: frame_0169_jpg.rf.2f3d695fba8d5bae276bdad31f1c91d7.jpg
# Processando: frame_0170_jpg.rf.a56786f85d0987646deebd1c7b2e8b6f.jpg
# Processando: frame_0171_jpg.rf.baad42e447ce6ccca3d7549727d27d66.jpg
# Processando: frame_0172_jpg.rf.096a509e7908f4e3b39c5e958b403ee2.jpg
# Processando: frame_0173_jpg.rf.7f7ba5d3b60b7b9b208b7e7d02f7334d.jpg
# Processando: frame_0174_jpg.rf.a73f50a44e16175466240133622798a3.jpg
# Processando: frame_0175_jpg.rf.065278f2991879bfc4b41e186eef1cee.jpg
# Processando: frame_0176_jpg.rf.586e6a373f820fc8b130d7bb8e8e4354.jpg
# Processando: frame_0177_jpg.rf.a2b6b9807634a2f03594f58064e9371f.jpg
# Processando: frame_0178_jpg.rf.9f3578325f4291854c8d83bbd6170e7b.jpg
# Processando: frame_0179_jpg.rf.f6e71ee45797cc8da1793da13c23c7bf.jpg
# Processando: frame_0180_jpg.rf.64143d4000506ce593b8a98764f9fddb.jpg
# Processando: frame_0181_jpg.rf.557a1b5473c4edf1a7a6073406c91858.jpg
# Processando: frame_0182_jpg.rf.d998f620ae40dc7bf7d982a41fb65e8e.jpg
# Processando: frame_0183_jpg.rf.a8be69d2b96a0dd0db90b8dcfc3281cf.jpg
# Processando: frame_0184_jpg.rf.88d31ecd5936b9108d9a94726a6b574b.jpg
# Processando: frame_0185_jpg.rf.4d3f64b96df5301e36b4d9def9ae02e9.jpg
# Processando: frame_0186_jpg.rf.3bc1dc27d0b0b715447853a315d09ef1.jpg
# Processando: frame_0187_jpg.rf.92d2d6e38d7865795ad268ca260074ca.jpg
# Processando: frame_0188_jpg.rf.6e8ae0b166e9ac5474d803bb68762ab0.jpg
# Processando: frame_0189_jpg.rf.babb5d63d9ac9d0ba8312bf2243a5e76.jpg
# Processando: frame_0190_jpg.rf.9b53ba71f0f68be4acef199ecd974c80.jpg
# Processando: frame_0191_jpg.rf.7b0438c96acf4295957e9c58172fc34f.jpg
# Processando: frame_0192_jpg.rf.ced5081d53878cc75526a7f1f3b1f3e5.jpg
# Processando: frame_0193_jpg.rf.b80986b47e883f0f09804d75416ff366.jpg
# Processando: frame_0194_jpg.rf.791171acd85ced39fa4a9ef010638a3b.jpg
# Processando: frame_0195_jpg.rf.60b0294d0c07f3b0389b3e07d0c0e20f.jpg
# Processando: frame_0196_jpg.rf.3206acd2b6149900312d1f7e5b346c3f.jpg
# Processando: frame_0197_jpg.rf.02752f489fd0d209c62996b85aab882a.jpg
# Processando: frame_0198_jpg.rf.d809ecef034d205c1ca748629aef2b5f.jpg
# Processando: frame_0199_jpg.rf.809ac90227203614070989e795216dfd.jpg
# Processando: frame_0200_jpg.rf.46cc25b6875d214f9da8fe9d8c797e67.jpg
# Processando: frame_0201_jpg.rf.916fd08d726085a0f95f0f3435b36955.jpg
# Processando: frame_0202_jpg.rf.2266e56d96ac765cf9270108991f991b.jpg
# Processando: frame_0203_jpg.rf.82343276b4b6a5e9d8112adce5248204.jpg
# Processando: frame_0204_jpg.rf.7ff96d38cf3c5727703b913093757cf9.jpg
# Processando: frame_0205_jpg.rf.57b6545e3d23dfb95528b0dd05a2186d.jpg
# Processando: frame_0206_jpg.rf.741c6d797390928b3aec2e16af63b3e2.jpg
# Processando: frame_0207_jpg.rf.82434ee0286197a91a2b597532bc2a80.jpg
# Processando: frame_0208_jpg.rf.b9b00d6a94e1ca9aeec442e5f8635b23.jpg
# Processando: frame_0209_jpg.rf.f59c2346355e7a3b678cc192c898dc36.jpg
# Processando: frame_0210_jpg.rf.fb481393a36cc3b8d09f5bc6260d82e4.jpg
# Processando: frame_0211_jpg.rf.84fa216d7cc5b066664a8c066fbea6f5.jpg
# Processando: frame_0212_jpg.rf.31f3b31e8e82eba7c657fdb778303430.jpg
# Processando: frame_0213_jpg.rf.7ba2d25bbd23af7e0ff0900c8db37ba8.jpg
# Processando: frame_0214_jpg.rf.7f950f7db56b929cd19b985aabe51401.jpg
# Processando: frame_0215_jpg.rf.6bc0d849af4c30088bbc0c44578c3aba.jpg
# Processando: frame_0216_jpg.rf.74761675a2cc93036b5dd4e5e42ca02e.jpg
# Processando: frame_0217_jpg.rf.2e84948154c7fbb556f6a352b6fec327.jpg
# Processando: frame_0218_jpg.rf.cdddcce8c765436d1f0da8cf0ed2dbc4.jpg
# Processando: frame_0219_jpg.rf.12fcca3a1ceed97b0c51f333a6058585.jpg
# Processando: frame_0220_jpg.rf.8e345128863d8c9ac323f3912ad874d3.jpg
# Processando: frame_0221_jpg.rf.1bebb7b057d3737b0e2dd9695fed3f01.jpg
# Processando: frame_0222_jpg.rf.ebde783e22c0fe442390935abbbc9214.jpg
# Processando: frame_0223_jpg.rf.462a9cd6cb08dce8089679fdc934e478.jpg
# Processando: frame_0224_jpg.rf.c8f212bdcb5b98ae5f26eb2533bad6d0.jpg
# Processando: frame_0225_jpg.rf.dd00b0c6df1bd1c82ca4a99d3b300aca.jpg
# Processando: frame_0226_jpg.rf.e065a16ac316ddc32cf254412a46ef27.jpg
# Processando: frame_0227_jpg.rf.23e0fa3276fa72b42c98ee79e76e53e1.jpg
# Processando: frame_0228_jpg.rf.3b689cf311a8804747a88110a296c6fe.jpg
# Processando: frame_0229_jpg.rf.98c05895944711e503496e2d7dd6b39a.jpg
# Processando: frame_0230_jpg.rf.8f6cc1f22b404d844650fd8fd4903b33.jpg
# Processando: frame_0231_jpg.rf.c11199c0d910c37b4c9228a6c989f3d4.jpg
# Processando: frame_0232_jpg.rf.8b97b97113204445f33e6dafaf8809de.jpg
# Processando: frame_0233_jpg.rf.1804c1b67fae34f0abac66d655a0821c.jpg
# Processando: frame_0234_jpg.rf.dbb2850ae689a8cac25752485ec1d898.jpg
# Processando: frame_0235_jpg.rf.64f6e456c17b4ffdd054ab02f70afaa9.jpg
# Processando: frame_0236_jpg.rf.c94f4d0a757750689c4984c6eee2b4e8.jpg
# Processando: frame_0237_jpg.rf.bbbcc2d1bd08281ecbd6e31063f28121.jpg
# Processando: frame_0238_jpg.rf.4adc89a62041e4e804fd308b162af0ee.jpg
# Processando: frame_0239_jpg.rf.0a77e0a3c0eb430bbd86ca9fb32624f7.jpg
# Processando: frame_0240_jpg.rf.87bec2508cefbeaeb617f7efd733c9d3.jpg
# Processando: frame_0241_jpg.rf.58aa20ff44f116f5bd2271b8321512ff.jpg
# Processando: frame_0242_jpg.rf.6e3ab7d04ea81ea102d2a33a92eee3ce.jpg
# Processando: frame_0243_jpg.rf.d9244179e0075f2a40f68c1bb4050747.jpg
# Processando: frame_0244_jpg.rf.4e8cefac60f7c20ffa74ec57d129169e.jpg
# Processando: frame_0245_jpg.rf.543fb16817e9463ef8e114f3c37e7a8a.jpg
# Processando: frame_0246_jpg.rf.e2776fcedb784cb60d921b85a6e0cdd2.jpg
# Processando: frame_0247_jpg.rf.01eab7fd0ffcf8d41a08cd454ae2e96d.jpg
# Processando: frame_0248_jpg.rf.e49f572f25e35bf90b0983b6397b0fc8.jpg
# Processando: frame_0249_jpg.rf.b6eea3a546d177d01a265d5563483c74.jpg
# Processando: frame_0250_jpg.rf.9d8ba11678f857e5190c7bbd34c15cca.jpg
# Processando: frame_0251_jpg.rf.d71aa7bb43bc6826497885ecc3a60919.jpg
# Processando: frame_0252_jpg.rf.e0920661630fe1b23acd2ee2ec7a0b84.jpg
# Processando: frame_0253_jpg.rf.66c4946b75460721ab169ef94de915a1.jpg
# Processando: frame_0254_jpg.rf.d4fb2b684ade9ac3efddc4e4e6a457c8.jpg
# Processando: frame_0255_jpg.rf.a0448d87cf508f2514e89b54a74e2a93.jpg
# Processando: frame_0256_jpg.rf.91df58e01644d6cdd2e6c44642156e40.jpg
# Processando: frame_0257_jpg.rf.1d00e20e35b96c091b624d172548e882.jpg
# Processando: frame_0258_jpg.rf.679123d6fc7c915f14a83b3d738ff61f.jpg
# Processando: frame_0259_jpg.rf.c2d7791c3c5cf8c9169719c9a43e2ddc.jpg
# Processando: frame_0260_jpg.rf.0bccdcc3946bad86c84289ac3c6c98d5.jpg
# Processando: frame_0261_jpg.rf.d99b693afd535948bcbeeb003613efdd.jpg
# Processando: frame_0262_jpg.rf.3e2ce724318e0b470f99262150ac3c0e.jpg
# Processando: frame_0263_jpg.rf.f8c3ebab38cd986b851ece50b2f698fd.jpg
# Processando: frame_0264_jpg.rf.de1c4cdeb1164d0403a8d171cf095c98.jpg
# Processando: frame_0265_jpg.rf.5547147fd0ee72e1622d3feb79ab74f4.jpg
# Processando: frame_0266_jpg.rf.ecdf4a4b8046b6181c5bd973dd40f7d4.jpg
# Processando: frame_0267_jpg.rf.5c2904ce3eeace249104de9339e2fab8.jpg
# Processando: frame_0268_jpg.rf.9b18adb8d18be4835b55817e41bc540d.jpg
# Processando: frame_0269_jpg.rf.39aa7a83d94ef815c153239847a83303.jpg
# Processando: frame_0270_jpg.rf.e481a4d8e8eafde747f5a5a020c8aafd.jpg
# Processando: frame_0271_jpg.rf.a8274364d9c7e4d6fb056b5a73a94315.jpg
# Processando: frame_0272_jpg.rf.23bfb7955536e64f3e8a33d5a2090ccf.jpg
# Processando: frame_0273_jpg.rf.c53d209b929281a7c6363d720f5e5fd9.jpg
# Processando: frame_0274_jpg.rf.4eba6c2a9a5face71f1efbb5566bf1da.jpg
# Processando: frame_0275_jpg.rf.fa8d01e29ca9880555caf4f250c71600.jpg
# Processando: frame_0276_jpg.rf.2cd68eecf63037cde8e383c6cc2fd8b1.jpg
# Processando: frame_0277_jpg.rf.fcaae77c6e6b4cdc63055397d146b6ad.jpg
# Processando: frame_0278_jpg.rf.760f29418e7b8cf0b6421a07731575f5.jpg
# Processando: frame_0279_jpg.rf.dff93052f3c64c48c513c1febbe3fe1b.jpg
# Processando: frame_0280_jpg.rf.9ecd1bd0ad75bddc2169f87c04bf9ce1.jpg
# Processando: frame_0281_jpg.rf.8d4f496e5ee2e4bf5cd99674c9a03e3b.jpg
# Processando: frame_0282_jpg.rf.2dc9a94b5d810b595c62a74f644491d1.jpg
# Processando: frame_0283_jpg.rf.246545ce0df3a3f0ae5d8b66c9cc3047.jpg
# Processando: frame_0284_jpg.rf.632cef23ffbe2e3e8e7a77b8f9101fad.jpg
# Processando: frame_0285_jpg.rf.503cda007e468f50f9d5cf834f9f5f46.jpg
# Processando: frame_0286_jpg.rf.97da8dc23795dcf2a9ff0b9a4f16f632.jpg
# Processando: frame_0287_jpg.rf.63312c012852888e933558a8bdc0696c.jpg
# Processando: frame_0288_jpg.rf.59ea6bddbf6faa272731b893ade61ee6.jpg
# Processando: frame_0289_jpg.rf.c920495bc99846883805b30fa93f486d.jpg
# Processando: frame_0290_jpg.rf.11e986aa72b882389756b6cf11479d1c.jpg
# Processando: frame_0291_jpg.rf.1b6ba4d8269351797260ef2c6e04a8d3.jpg
# Processando: frame_0292_jpg.rf.84da575b37e84f8cdc143a8855a74492.jpg
# Processando: frame_0293_jpg.rf.6a7f2c6403fd49d90b1eabdcb1c23300.jpg
# Processando: frame_0294_jpg.rf.68d155a7b92e13764483922314fd0781.jpg
# Processando: frame_0295_jpg.rf.f4a9de1e8febbd8f09f49548b2fccf50.jpg
# Processando: frame_0296_jpg.rf.c0abaf70ce60292c86dfc84335ac2a86.jpg
# Processando: frame_0297_jpg.rf.012e45afe30bbf124a788255ccad488a.jpg
# Processando: frame_0298_jpg.rf.ff85b7cb2d3f6ab4fbc7797c65fe4328.jpg
# Processando: frame_0299_jpg.rf.3bd77fc4362a46f8523ebb4984853536.jpg
# Processando: frame_0300_jpg.rf.e74463b707b335042d705d64f86d6df7.jpg
# Processamento finalizado.
